# %% [markdown]
# # Countries Economy, GDP and everything (From Kaggle)

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
import locale
import numpy as np

# %% [markdown]
# ### Importing dataset

# %%
df = pd.read_csv('countries-of-the-world.csv')

df.head(5)
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %% [markdown]
# #### Trimming the spaces on variables

# %%
df['Country'] = df['Country'].str.strip()
df['Region']  = df['Region'].str.strip()

# %% [markdown]
# #### Converting the numbers to float type and replacing ',' with '.'

# %%
columns_to_convert = ['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
    'Net migration', 'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 
    'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate','Agriculture', 'Industry', 'Service']

df[columns_to_convert] = df[columns_to_convert].replace(',', '.', regex=True)

# Convert the columns to float
df[columns_to_convert] = df[columns_to_convert].astype(float)

# %% [markdown]
# ### Creating a new column for overall GDP

# %%
df['GDP'] = df['GDP ($ per capita)'] * df['Population']

# %% [markdown]
# ### Sorting by GDP per capita

# %%
df_sort_GDPpc = df.sort_values('GDP ($ per capita)', ascending= False)

# %% [markdown]
# #### Top 10 GDPs Per Capita in the World

# %%
style.use('default')
plt.figure(figsize= (12,4))
plt.title('Top 10 GDPs Per Capita', fontsize = 20)

# Ploting the bar graph
x = df_sort_GDPpc['Country'].head(10)
y = df_sort_GDPpc['GDP ($ per capita)'].head(10)
plt.bar(x, y, width= 0.5)

#Setting the size of the y axis
plt.ylim(0, max(y) * 1.1)

# Hide the y-axis scale
plt.gca().axes.get_yaxis().set_visible(False)
plt.xticks(rotation=-30)


# GDP per capita values above each bar
for i, gdp_per_cap in enumerate(df_sort_GDPpc['GDP ($ per capita)'].head(10)):
    plt.text(i, gdp_per_cap, str(int(gdp_per_cap)), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# ### Sorting by GDP

# %%
df_sort_GDP = df.sort_values('GDP', ascending= False)

# %%
style.use('default')
plt.figure(figsize= (12,4))
plt.title('Top 10 GDP', fontsize = 20)

x = df_sort_GDP['Country'].head(10)
y = df_sort_GDP['GDP'].head(10)

# Ploting the bar graph
plt.bar(x, y, width= 0.5)

#Setting the size of the y axis
plt.ylim(0, max(y) * 1.1)
# Hide the y-axis scale
plt.gca().axes.get_yaxis().set_visible(False)
plt.xticks(rotation=-30)


# GDP per capita values above each bar
for i, gdp in enumerate(df_sort_GDP['GDP'].head(10)):
    # Formatting GDP like billions
    formatted_gdp = locale.format_string('%.2f tri', gdp / 1e12)
    plt.text(i, gdp, str(formatted_gdp), ha='center', va= 'bottom')


plt.show()

# %% [markdown]
# ### Analyzing the relation between Literacy and GDP Per Capita

# %%
df = df.dropna(subset=['Literacy (%)'])
plt.title('GDP Per Capita x Literacy (%)', fontsize = 15)

x = df['Literacy (%)']
y = df['GDP ($ per capita)']

plt.scatter(x, y)

plt.show()

# %% [markdown]
# ### Does money bring happiness?

# %% [markdown]
# We can take a look at how happy the people from each nation are and if that seems to be correlated to its GDP per capita data

# %% [markdown]
# ### Importing World Happiness Dataset

# %%
wh = pd.read_csv(r"C:\Users\erick\Jupyter\Countries Economics\World Happiness Data\2019.csv")
    
wh.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# 9                    1.016                         0.532       0.244
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
# 5                      0.343
# 6                      0.373
# 7                      0.380
# 8                      0.308
# 9                      0.226

# %% [markdown]
# ### Merging it with our economy dataframe

# %%
    df_merged = pd.merge(df, wh[['Country or region', 'Score']], left_on='Country', right_on='Country or region', how='inner')

    df_merged
# Out:
#          Country                Region  Population  Area (sq. mi.)  \
# 0    Afghanistan  ASIA (EX. NEAR EAST)  31056997.0        647500.0
# 1        Albania        EASTERN EUROPE   3581655.0         28748.0
# 2        Algeria       NORTHERN AFRICA  32930091.0       2381740.0
# 3      Argentina   LATIN AMER. & CARIB  39921833.0       2766890.0
# 4        Armenia   C.W. OF IND. STATES   2976372.0         29800.0
# ..           ...                   ...         ...             ...
# 137    Venezuela   LATIN AMER. & CARIB  25730435.0        912050.0
# 138      Vietnam  ASIA (EX. NEAR EAST)  84402966.0        329560.0
# 139        Yemen             NEAR EAST  21456188.0        527970.0
# 140       Zambia    SUB-SAHARAN AFRICA  11502010.0        752614.0
# 141     Zimbabwe    SUB-SAHARAN AFRICA  12236805.0        390580.0
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                          48.0                          0.00          23.06
# 1                         124.6                          1.26          -4.93
# 2                          13.8                          0.04          -0.39
# 3                          14.4                          0.18           0.61
# 4                          99.9                          0.00          -6.47
# ..                          ...                           ...            ...
# 137                        28.2                          0.31          -0.04
# 138                       256.1                          1.05          -0.45
# 139                        40.6                          0.36           0.00
# 140                        15.3                          0.00           0.00
# 141                        31.3                          0.00           0.00
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                                163.07               700.0          36.0
# 1                                 21.52              4500.0          86.5
# 2                                 31.00              6000.0          70.0
# 3                                 15.18             11200.0          97.1
# 4                                 23.28              3500.0          98.6
# ..                                  ...                 ...           ...
# 137                               22.20              4800.0          93.4
# 138                               25.95              2500.0          90.3
# 139                               61.50               800.0          50.2
# 140                               88.29               800.0          80.6
# 141                               67.69              1900.0          90.7
#
#      ...  Other (%)  Climate  Birthrate  Deathrate  Agriculture  Industry  \
# 0    ...      87.65      1.0      46.60      20.34        0.380     0.240
# 1    ...      74.49      3.0      15.11       5.22        0.232     0.188
# 2    ...      96.53      1.0      17.14       4.61        0.101     0.600
# 3    ...      87.21      3.0      16.73       7.55        0.095     0.358
# 4    ...      80.15      4.0      12.07       8.23        0.239     0.343
# ..   ...        ...      ...        ...        ...          ...       ...
# 137  ...      96.13      2.0      18.71       4.92        0.040     0.419
# 138  ...      74.08      2.0      16.86       6.22        0.209     0.410
# 139  ...      96.98      1.0      42.89       8.30        0.135     0.472
# 140  ...      92.90      2.0      41.00      19.93        0.220     0.290
# 141  ...      91.34      2.0      28.01      21.84        0.179     0.243
#
#      Service           GDP  Country or region  Score
# 0      0.380  2.173990e+10        Afghanistan  3.203
# 1      0.579  1.611745e+10            Albania  4.719
# 2      0.298  1.975805e+11            Algeria  5.211
# 3      0.547  4.471245e+11          Argentina  6.086
# 4      0.418  1.041730e+10            Armenia  4.559
# ..       ...           ...                ...    ...
# 137    0.541  1.235061e+11          Venezuela  4.707
# 138    0.381  2.110074e+11            Vietnam  5.175
# 139    0.393  1.716495e+10              Yemen  3.380
# 140    0.489  9.201608e+09             Zambia  4.107
# 141    0.579  2.324993e+10           Zimbabwe  3.663
#
# [142 rows x 23 columns]

# %% [markdown]
# ### Analyzing relationship between Happiness and GDP per capita

# %%
plt.figure(figsize= (10,5))

plt.title('Happiness x GDP per capita', fontsize = 15)

y = df_merged['Score']
x = df_merged['GDP ($ per capita)']

plt.scatter(x, y)

plt.show()

# %% [markdown]
# #### Performing Linear Regression (y = a + bx)

# %%
from sklearn.linear_model import LinearRegression

y = df_merged['Score']
x = df_merged['GDP ($ per capita)']

reg = LinearRegression().fit(x.values.reshape(-1, 1),y)

# %%
a = reg.intercept_
b = reg.coef_

Y = a + b * x
# Calculating R²
r2 = reg.score(x.values.reshape(-1, 1),y)

plt.figure(figsize= (10,5))
plt.title('Linear Regression: Happiness x GDP per capita', fontsize = 12)

y = df_merged['Score']
x = df_merged['GDP ($ per capita)']

plt.scatter(x, y)
plt.plot(x, Y, '--r')

print(f'y = {round(a, 2)} + {float(b)}x    R² = {round(r2, 2)}')

plt.show()
# Out:
# y = 4.68 + 7.915442776015031e-05x    R² = 0.57

# %% [markdown]
# Visualizing our regression line, we can see the upwards trend. The greater the GDP per capita, the happier the country will. However, our model isn't the most accurate, as we can see by our R² value of 0.57. The closer our R² gets to 1 the better.
#
# Another clear issue of the model, it's that it implies that happiness can increase above the 10 mark, although the score goes from 0 to 10

# %% [markdown]
# We can also see that the observation with the greater GDP per capita (USA) is far from having the greater happiness score. And its positioning on the graph may suggest that after a certain level of GDP per capita, happiness may actually decrease. That kind of behavior can be translated in quadratic functions. Therefore, it might me interesting to perform a quadratic regression and test if it fits the data better than the linear, and if we get a R² closer to 1.

# %% [markdown]
# ### Performing a quadratic regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

X = df_merged['GDP ($ per capita)'].values.reshape(-1, 1) 
y = df_merged['Score']  # Explained variable

# Converting features to polynomies of degree 2
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)

# Creating and adjusting the regression model
reg = LinearRegression().fit(X_poly, y)

coef = reg.coef_
c = reg.intercept_

# Calcular R²
r2 = reg.score(X_poly,y)

# Printing the regression function
print(f"y = {coef[2]} x² + {coef[1]}x + {round(c,2)}     R² = {round(r2, 2)} ")

# Y = (coef[2] * X ** 2) + (coef[1] * X)+ c

# Gerar valores para a variável explicativa
x_values = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)

# Prever os valores correspondentes da variável explicada usando o modelo ajustado
y_pred = reg.predict(poly_features.transform(x_values))

plt.figure(figsize= (10,5))

plt.title("Quadratic Regression")
plt.xlabel('GDP per capita')
plt.ylabel('Happiness Score')

plt.scatter(X,y)

plt.plot(x_values, y_pred, '--r')

plt.show()
# Out:
# y = -1.814977783336037e-09 x² + 0.00014231745350089478x + 4.44     R² = 0.62

# %% [markdown]
# That's it. Now we have an R² that is a lit bit closer to one. But the most important thing is: our regression no longer implies that the happiness score can surpass its own limited scale.

# %% [markdown]
# We can also calculate which would the certain level of GDP per capita that after it, happiness would decrease instead of increasing. That would be the x (GDP per capita) value that gives the maximum value of y (happiness) of the quadratic function we found

# %%
max_index = np.argmax(y_pred)

# Assuming x_values is the array of x values used in the regression
x_max = x_values[max_index]

print(f'$ {round(float(x_max))} per capita')
# Out:
# $ 39106 per capita

# %% [markdown]
# Therefore, according to our model, after the $ 39106 per capita mark, people are not getting any happier.
